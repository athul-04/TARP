# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv(r'F:\TARP\res1.csv')
df1=df1[["Time","Drowsy"]]

df2 = pd.read_csv(r'F:\TARP\res2.csv')
df2=df2[["Time","Drowsy"]]

df3 = pd.read_csv(r'F:\TARP\res3.csv')
df3=df3[["Time","Drowsy"]]

# %%
d1 = pd.DataFrame(columns=['Time', 'Drowsy'])
d1.Time = pd.date_range("7:59", "17:00", freq="1min").strftime('%H:%M')
drw=[]
drw.append(1)
for i in range(1,len(d1)):
    drw.append(0)
t=df1.Time
d1.Drowsy =drw
for i in t:
    d1.loc[d1.Time == i, ['Drowsy']] = 1

sns.lineplot(d1)
# Out:
# <AxesSubplot: >

# %%
d2 = pd.DataFrame(columns=['Time', 'Drowsy'])
d2.Time = pd.date_range("7:59", "17:00", freq="1min").strftime('%H:%M')
drw=[]
drw.append(1)
for i in range(1,len(d1)):
    drw.append(0)
t=df2.Time
d2.Drowsy =drw
for i in t:
    d2.loc[d2.Time == i, ['Drowsy']] = 1

sns.lineplot(d2)
# Out:
# <AxesSubplot: >

# %%
d3 = pd.DataFrame(columns=['Time', 'Drowsy'])
d3.Time = pd.date_range("7:59", "17:00", freq="1min").strftime('%H:%M')
drw=[]
drw.append(1)
for i in range(1,len(d1)):
    drw.append(0)
t=df3.Time
d3.Drowsy =drw
for i in t:
    d3.loc[d3.Time == i, ['Drowsy']] = 1

sns.lineplot(d3)
# Out:
# <AxesSubplot: >

# %%
e1=d1['Drowsy']
e2=d2['Drowsy']
e3=d3['Drowsy']
e1=list(e1)
e1=["e1" if x==0 else x for x in e1]
e2=list(e2)
e2=["e2" if x==0 else x for x in e2]
e3=list(e3)
e3=["e3" if x==0 else x for x in e3]

# %%
print(e1)
print(e2)
print(e3)
# Out:
# [1, 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1', 'e1'
# ...

# %%
len(e1)
# Out:
# 542

# %%
e=[]
l=[]
c=0
while(e1[c]!=1):
    e.append(e1[c])
    c+=1
n=len(e1)
c1=0
c2=0
c3=0
for i in range(c,n):
    if(e1[i]!=1) and c1<=n//3:
        e.append(e1[i])
        c1+=1
    elif(e2[i]!=1) and c2<=n//3:
        e.append(e2[i])
        c2+=1
    elif c3<=n//3:
        e.append(e3[i])
        c3+=1

# %%
c1=c2=c3=0
for i in e:
    if i=="e1":
        c1+=1
    elif i=="e2":
        c2+=1
    else:
        c3+=1
print(c1,c2,c3)
# Out:
# 181 181 180

# %%
for i in range(len(e3)):
    if e[i]=="e1":
        e[i]=1
    elif e[i]=="e2":
        e[i]=2
    else:
        e[i]=3

# %%
s = pd.DataFrame(columns=['Time', 'Shift'])
s.Time = pd.date_range("7:59", "17:00", freq="1min").strftime('%H:%M')
s.Shift = e

# %%
sns.lineplot(e)
# Out:
# <AxesSubplot: >
